# %%
import pandas as pd

# %%
data = {
    'name':['a','b','c'],
    'age': [23,53,13],
}

df = pd.DataFrame(data)
df
# Out:
#   name  age
# 0    a   23
# 1    b   53
# 2    c   13

# %%
df = pd.read_csv('./data.csv')
df
# Out:
#       name  age  salary
# 0      ali   22     100
# 1      mmd   24     112
# 2   kamran   35    1233
# 3    majid   35     943
# 4  morteza   24     133
# 5    kimia   34     233
# 6    elahe   24     242

# %%
df.head()
# Out:
#       name  age  salary
# 0      ali   22     100
# 1      mmd   24     112
# 2   kamran   35    1233
# 3    majid   35     943
# 4  morteza   24     133

# %%
df.describe()
# Out:
#              age       salary
# count   7.000000     7.000000
# mean   28.285714   428.000000
# std     6.019809   461.940833
# min    22.000000   100.000000
# 25%    24.000000   122.500000
# 50%    24.000000   233.000000
# 75%    34.500000   592.500000
# max    35.000000  1233.000000

# %%
df['name']
# Out:
# 0        ali
# 1        mmd
# 2     kamran
# 3      majid
# 4    morteza
# 5      kimia
# 6      elahe
# Name: name, dtype: object

# %%
df.iloc[2,:]
# Out:
# name      kamran
# age           35
# salary      1233
# Name: 2, dtype: object

# %%
df.iloc[2,1]
# Out:
# 35

# %%
filtered_df = df[df['salary'] > 300]
filtered_df
# Out:
#      name  age  salary
# 2  kamran   35    1233
# 3   majid   35     943

# %%
sorted_df = df.sort_values('salary', ascending=False)
sorted_df
# Out:
#       name  age  salary
# 2   kamran   35    1233
# 3    majid   35     943
# 6    elahe   24     242
# 5    kimia   34     233
# 4  morteza   24     133
# 1      mmd   24     112
# 0      ali   22     100

# %%
subset = df.loc[2:4, ['name', 'age']]
subset
# Out:
#       name  age
# 2   kamran   35
# 3    majid   35
# 4  morteza   24

# %%
df_grouped = df.groupby('age')
df_grouped

# %%
df_grouped.count()
# Out:
#      name  salary
# age
# 22      1       1
# 24      3       3
# 34      1       1
# 35      2       2

# %%
df['test'] = [1,2,3,4,5,6,7]
df
# Out:
#       name  age  salary  test
# 0      ali   22     100     1
# 1      mmd   24     112     2
# 2   kamran   35    1233     3
# 3    majid   35     943     4
# 4  morteza   24     133     5
# 5    kimia   34     233     6
# 6    elahe   24     242     7

# %%
df.drop('test', axis=1, inplace=True)
df
# Out:
#       name  age  salary
# 0      ali   22     100
# 1      mmd   24     112
# 2   kamran   35    1233
# 3    majid   35     943
# 4  morteza   24     133
# 5    kimia   34     233
# 6    elahe   24     242

# %%
len(df)
# Out:
# 7

# %%
df.loc[len(df)] = {
    'name': 'Test',
    'age': 22
}

df
# Out:
#       name  age  salary
# 0      ali   22   100.0
# 1      mmd   24   112.0
# 2   kamran   35  1233.0
# 3    majid   35   943.0
# 4  morteza   24   133.0
# 5    kimia   34   233.0
# 6    elahe   24   242.0
# 7     Test   22     NaN

# %%
df.isna()
# Out:
#     name    age  salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False    True

# %%
df1 = df.dropna()
df1
# Out:
#       name  age  salary
# 0      ali   22   100.0
# 1      mmd   24   112.0
# 2   kamran   35  1233.0
# 3    majid   35   943.0
# 4  morteza   24   133.0
# 5    kimia   34   233.0
# 6    elahe   24   242.0

# %%
df2 = df.fillna(0)
df2
# Out:
#       name  age  salary
# 0      ali   22   100.0
# 1      mmd   24   112.0
# 2   kamran   35  1233.0
# 3    majid   35   943.0
# 4  morteza   24   133.0
# 5    kimia   34   233.0
# 6    elahe   24   242.0
# 7     Test   22     0.0

# %%
df.to_csv('newdata.csv')
